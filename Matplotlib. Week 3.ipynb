# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

# %%
#Subplot(s)

# %%
x=np.arange(5, 60, 5)
y1=x**1.5
y2=x**1.9
y3=x**2

# %%
plt.figure()
plt.subplot(1, 2, 1)
plt.plot(x, y1, "-o", c="red")
plt.plot(x, y2, "-o", c="blue")
plt.subplot(1, 2, 2)
plt.plot(x, y3, "-o", c="green")
# Out:
# <img src="data:image/png;base64,..." width="927.2727071746326">

# %%
x=np.arange(5, 60, 5)
z=np.arange(5, 80, 5)
y1=x**2
y2=z**2.5
plt.figure()
ax1=plt.subplot(1, 2, 1)
plt.plot(x, y1, "-o", c="red")
ax2=plt.subplot(1, 2, 2, sharex=ax1, sharey=ax1)
plt.plot(z, y2, "-o", c="blue")
# Out:
# <img src="data:image/png;base64,..." width="938.1817978472753">

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharex=True, sharey=True)
ax2.plot(x, y1, "-o", c="red")
ax4.scatter(z, y2, c="blue", s=50)
# Out:
# <img src="data:image/png;base64,..." width="881.8181627052878">

# %%
#Histograms

# %%
#Histograms are also BarChats with y-axis as fre. of variable

# %%
x=[12, 15, 17, 19, 34, 45, 56, 57, 78, 79, 89, 90, 99]
plt.figure()
plt.hist(x, bins=8, color="green")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# (array([4., 0., 1., 1., 2., 0., 2., 3.]),
#  array([12.   , 22.875, 33.75 , 44.625, 55.5  , 66.375, 77.25 , 88.125,
#         99.   ]),
#  <a list of 8 Patch objects>)

# %%
x=[12, 15, 17, 19, 34, 45, 56, 57, 78, 79, 89, 90, 99]
plt.figure()
plt.hist(x, bins=[0, 30, 60, 100], color="green")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# (array([4., 4., 5.]), array([  0,  30,  60, 100]), <a list of 3 Patch objects>)

# %%
y=np.arange(5, 100, 9)
plt.figure()
plt.hist([x, y], bins=[0, 30, 60, 100], color=["red", "blue"], orientation="horizontal")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# ([array([4., 4., 5.]), array([3., 4., 4.])],
#  array([  0,  30,  60, 100]),
#  <a list of 2 Lists of Patches objects>)

# %%
plt.legend(["A", "B"], title="legend")

# %%
#Boxplots

# %%
import pandas as pd
val=pd.Series(x)
val.describe()
# Out:
# count    13.000000
# mean     53.076923
# std      31.765971
# min      12.000000
# 25%      19.000000
# 50%      56.000000
# 75%      79.000000
# max      99.000000
# dtype: float64

# %%
plt.figure()
plt.boxplot(x)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# {'whiskers': [<matplotlib.lines.Line2D at 0x26650e85e80>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x26650e8f828>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x26650e85d30>],
#  'medians': [<matplotlib.lines.Line2D at 0x26650e8feb8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x26650e8ff98>],
#  'means': []}

# %%
t=np.linspace(3, 9, 10)
t
# Out:
# array([3.        , 3.66666667, 4.33333333, 5.        , 5.66666667,
#        6.33333333, 7.        , 7.66666667, 8.33333333, 9.        ])
